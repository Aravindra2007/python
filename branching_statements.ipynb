# %%
#simple if(only oif present there is no existance of else)
a = 10  
if a:  # for only a = 0 it will print else statement(for +ve and -ve it will print if )
    print(a," is a greater ")
# Out:
# 10  is a greater

# %%
# if else statement
a =30
b = 20
if a > b:
    print("a is a greter than b ")   #indentetion is mandotory
    a = 34
else:
    print(a," is lesser")
    b =25
print(a,b)
# Out:
# a is a greter than b
# 34 20

# %%
# if -elif statement (more than 2 conditions can be applied)
if 2:
    print(" 2 ")
elif 3:      ## only if above condition is false than it will execute
    print("3")
else:
    print("4")
# Out:
#  2

# %%
# write pp to calculate current bill  based on no of units consumed the following is the tarrif for unit 0 to 200= 3 ,201 to 250 = 4,251 to 300 = 6,301 to 400 = 8, 401 and above = 12 calaculate the final bill
units = int(input("Enter the No of units "))  ##input 265 output 890 for dividing method for normal method 1590
if units < 200:
    tarif = 3
elif units <250:
    tarif = 4
elif units < 300:
    tarif = 6
elif units <400:
    tarif = 8
else:
    tarif = 12

total_bill = tarif * units
print("Total Bill Amount is : ",total_bill)
# Out:
# Total Bill Amount is :  1590

# %%
units = int(input("Enter the Number units consumed "))
if units < 200:
    tarif = 3
    total = tarif *3
elif units <250:
    u1 = units % 200
    tarif = 4
    tu1 = u1 * tarif
    total = 200 * 3 + tu1
elif units < 300:
    u1 = units % 200
    u2 = units % 250
    tu1 = (u1 - u2) * 4
    tu2 = u2 * 6
    total = 200 * 3 + tu1 + tu2
elif units <400:
    u1 = units % 200
    u2 = units % 250
    u3 = units % 300
    tu1 = (u1 - u2) * 4
    tu2 = (u2 - u3) * 6
    tu3 =  u3 * 8
    total = 200 * 3 + tu1 + tu2 + tu3
else:
    u1 = units % 200
    u2 = units % 250
    u3 = units % 300
    u4 = units % 400
    tu1 = (u1 - u2) * 4
    tu2 = (u2 - u3) * 6
    tu3 = (u3 - u4) * 8
    tu4 = u4 * 12
    total = 200 * 3 + tu1 + tu2 + tu3 + tu4

print("Total Amount : ",total)
# Out:
# Total Amount :  890

# %%
units = int(input("Enter the Number units consumed "))
if units < 200:
    total = (200 - units) * 3
elif units <250:
    total = (units - 200) * 4 + (200 *3)
elif units < 300:
    total = (units - 250) * 6 + (250-200)*4 + 200*3
elif units <400:
    total = (units - 300) * 8 + (300-250)*6 + (250-200)*4 + 200*3
else:
    total = (units - 400) * 12 + (400-300) * 8 + (300-250)*6 + (250-200)*4 + 200*3

print("Total Amount : ",total)
# Out:
# Total Amount :  890

# %%
#nested If (1 if inside another if loop)
age = int(input("Enter the Age : "))
nation = input("enter The Nation : ")

if nation == "India" or "india":
    if age >= 18:
        print("Elgible For Participating in Election ")
    else:
        print("Not Eligible for voting  ")
else:
    print("Not Eligible for voting  ")
# Out:
# Elgible For Participating in Election

# %%
##logical opeartors in conditions(and ,or, not)
age = int(input("Enter the Age : "))
nation = input("enter The Nation : ")

if nation == "India" or "india" and age >= 18:
    print("Elgible For Participating in Election ")
else:
    print("Not Eligible for voting  ")
# Out:
# Elgible For Participating in Election

# %%
# Terinary Expression

age = int(input("Enter the Age : "))

result = "Elgible" if age > 18 else "Not Elgible "

print(result)
# Out:
# Elgible

# %%
num = int(input("Enter the number "))

rev = 0
temp = num
while temp >0:
    digit = temp%10
    rev = rev*10 + digit
    temp = temp//10

if num == rev:
    print("Palindrome ")
else:
    print("Not Palindrome ")
# Out:
# Not Palindrome

# %%
num = int(input("Enter The Number "))
fact = 1
for i in range(1,num+1):
    fact *= i

print(fact)
# Out:
# 120

# %%
num = int(input("Enter The Number "))
count = 0
while num > 0:
    num = num//10
    count += 1

print(count)
# Out:
# 5

# %%
text = input("Enter the TExt ")
count = 0
for i in text:
    count += 1

print(count)
# Out:
# 5

# %%
text = input("Enter the Text ")

rev = ""
for i in text:
    rev = i + rev

print(rev)
# Out:
# olleh

# %%
text = input("Enter the Text ")


for i,v in enumerate(text):
    print(i,v)
# Out:
# 0 h
# 1 e
# 2 l
# 3 l
# 4 o

# %%
text = input("Enter the Text ")
num = input("Enter the number ")
for i,v in zip(num,text):
    print(v)
# Out:
# a
# b
# c
# d

# %%
result = [x**2 for x in range(10,1,-1)]
print(result)

result.sort()
print(result)



result.sort(reverse=True)
print(result)
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4]
# [4, 9, 16, 25, 36, 49, 64, 81, 100]
# [100, 81, 64, 49, 36, 25, 16, 9, 4]
