# %% [markdown]
# ### Functions
# -> Predefined Functions(Builtin Functions)
#         python comes with a larage collection of predefined (it is already defined and comes with a and stored in a intrepreter)
# print()
# input()
# len()
# sort()
# type()

# %%
s = set([1,True])  ## any one thing will consider because both 1 and true are saem
s
# Out:
# {1}

# %%
d = {1:"hai",True:"hello"}     ## hai is replaced with hello
d
# Out:
# {1: 'hello'}

# %%
def h():
    print("Hello",name)
name = "aravind"
h()
# Out:
# Hello aravind

# %%
# write a pp using function to print even or odd
def div(num):
    if num%2 == 0:
        print("Even ")
    else:
        print("Odd ")

num = int(input("enter the Number :"))
div(num)



print("-"*50)

def div():
    if num%2 == 0:
        print("Even ")
    else:
        print("Odd ")

num = int(input("enter the Number :"))
div()
# Out:
# Odd
# --------------------------------------------------
# Even

# %%
def arthametic(a,d,n):
    count = 0
    while count < n:
        count +=1
        if count == 1:
            print(a,end=" ")
        else:
            next = a + d
            a = next
            print(next,end=" ")
        

arthametic(5,3,10)
# Out:
# 5 8 11 14 17 20 23 26 29 32
